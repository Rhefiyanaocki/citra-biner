# %%
from PIL import Image

# %%
def citra_biner(nilai_ambang):
    # konversi gambar RGB ke grayscale
    # https://stackoverflow.com/a/18778280/9157799
    CITRA_GRAYSCALE = Image.open('hii.png').convert('L')
    PIXEL_GRAYSCALE = CITRA_GRAYSCALE.load()

    ukuran_horizontal = CITRA_GRAYSCALE.size[0]
    ukuran_vertikal = CITRA_GRAYSCALE.size[1]

    for x in range(ukuran_horizontal):
        for y in range(ukuran_vertikal):
            if PIXEL_GRAYSCALE[x, y] < nilai_ambang:
                PIXEL_GRAYSCALE[x, y] = 0
            else:
                PIXEL_GRAYSCALE[x, y] = 255

    nama_setelah_disave = 'gambar_biner_' + str(nilai_ambang) + '.png'
    CITRA_GRAYSCALE.save(nama_setelah_disave)

# %%
citra_biner(50)

# %%
img = Image.open ('gambar_biner_50.png')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1269x637 at 0x26CF7ECFEE0>

# %%
citra_biner(128)

# %%
img = Image.open ('gambar_biner_128.png')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1269x637 at 0x26CF80A8AF0>

# %%
citra_biner(200)

# %%
img = Image.open ('gambar_biner_200.png')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1269x637 at 0x26CF7F75460>

# %%
citra_biner(230)

# %%
img = Image.open ('gambar_biner_230.png')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1269x637 at 0x26CF8134E50>

# %%
citra_biner(270)

# %%
img = Image.open ('gambar_biner_270.png')

# %%
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=L size=1269x637 at 0x26CF7F854F0>
